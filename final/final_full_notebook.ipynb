# %% [markdown]
# ### Declare a list containing the items {\tt x}, {\tt y} and {\tt z}, and assign the list to the variable {\tt lst}.

# %%
# your code here

# %% [markdown]
# ### Write a predicate that will be true if a list {\tt alist} is empty.

# %%
# your code here

# %% [markdown]
# ### Set the third element of a list {\tt alist} to 7.

# %%
# your code here

# %% [markdown]
# ### Print all elements of {\tt alist} except the first and last.

# %%
# your code here

# %% [markdown]
# ### Print the second half of {\tt alist}.

# %%
# your code here

# %% [markdown]
# ### Check if the value {\tt 13} is in a list called {\tt alist}.

# %%
# your code here

# %% [markdown]
# ### Assign a copy of {\tt alist} to {\tt blist}.

# %%
# your code here

# %% [markdown]
# ### Concatenate {\tt alist} and {\tt blist} and assign the result to {\tt clist}.

# %%
# your code here

# %% [markdown]
# ### Create a list consisting of 4 copies of {\tt alist}.

# %%
# your code here

# %% [markdown]
# ### Find the sum of {\tt alist} without looping.

# %%
# your code here

# %% [markdown]
# ### Find the minimum element of {\tt alist} without looping.

# %%
# your code here

# %% [markdown]
# ### Add the element {\tt `a'} to the end of {\tt alist}.

# %%
# your code here

# %% [markdown]
# ### Add the elements {\tt `a', `b', `c', `d'} to the end of {\tt alist} without looping.

# %%
# your code here

# %% [markdown]
# ### Remove the last element from list {\tt alist}.

# %%
# your code here

# %% [markdown]
# ### Remove the 4th element from {\tt alist}.

# %%
# your code here

# %% [markdown]
# ### Remove the element with the value {\tt `a'} from {\tt alist}.

# %%
# your code here

# %% [markdown]
# ### Convert the string {\tt “hello”} to the list {\tt ['h','e','l','l','o']}.

# %%
# your code here

# %% [markdown]
# ### Convert the string {\tt “Hello world!”} to the list {\tt ["Hello","world!"]}.

# %%
# your code here

# %% [markdown]
# ### Convert the string {\tt “Hello-world!”} to the list {\tt ["Hello","world!"]}.

# %%
# your code here

# %% [markdown]
# ### Convert the list {\tt ["Hello","world!"]} to the string {\tt "Hello world!"}.

# %%
# your code here

# %% [markdown]
# ### Loop over a list {\tt alist} and print each item.

# %%
# your code here

# %% [markdown]
# ### Loop over a list {\tt alist} in sorted order and print each item.

# %%
# your code here

# %% [markdown]
# ### Given a list {\tt alist} containing strings, use list comprehension to create a new list containing the length of each string.

# %%
# your code here

# %% [markdown]
# ### Given a = “banana” and b = “banana”, what is a == b?

# %%
# your code here

# %% [markdown]
# ### Given a = “banana” and b = “banana”, what is a is b?

# %%
# your code here

# %% [markdown]
# ### Given a = [1,2,3] and b = [1,2,3], what is a == b?

# %%
# your code here

# %% [markdown]
# ### Given a = [1,2,3] and b = [1,2,3], what is a is b?

# %%
# your code here

# %% [markdown]
# ### Given a=[1,2,3] and b=a, what is a is b?

# %%
# your code here

# %% [markdown]
# ### Create a copy of a called b such that a is b is False.

# %%
# your code here

# %% [markdown]
# ### Create an empty dictionary called d.

# %%
# your code here

# %% [markdown]
# ### Create dictionary lettermap mapping a,b,c to 1,2,3.

# %%
# your code here

# %% [markdown]
# ### Add key d to lettermap with value 4.

# %%
# your code here

# %% [markdown]
# ### Result of lettermap['e'].

# %%
# your code here

# %% [markdown]
# ### Result of lettermap.get('e').

# %%
# your code here

# %% [markdown]
# ### Result of lettermap.get('e',-1).

# %%
# your code here

# %% [markdown]
# ### Get length of lettermap.

# %%
# your code here

# %% [markdown]
# ### Check if key f is in lettermap.

# %%
# your code here

# %% [markdown]
# ### Print key-value pairs of lettermap.

# %%
# your code here

# %% [markdown]
# ### Print keys of lettermap.

# %%
# your code here

# %% [markdown]
# ### Print values of lettermap.

# %%
# your code here

# %% [markdown]
# ### Create tuple t=(3,4,5).

# %%
# your code here

# %% [markdown]
# ### Get length of tuple.

# %%
# your code here

# %% [markdown]
# ### Create empty tuple.

# %%
# your code here

# %% [markdown]
# ### Get first item of tuple.

# %%
# your code here

# %% [markdown]
# ### Get first two items of tuple.

# %%
# your code here

# %% [markdown]
# ### Concatenate t with u.

# %%
# your code here

# %% [markdown]
# ### Result of t[0]=6.

# %%
# your code here

# %% [markdown]
# ### Assign True to b1 and False to b2 in one line.

# %%
# your code here

# %% [markdown]
# ### Swap b1 and b2 in one line.

# %%
# your code here

# %% [markdown]
# ### Choose random element from t.

# %%
# your code here

# %% [markdown]
# ### Get current working directory.

# %%
# your code here

# %% [markdown]
# ### List contents of directory d.

# %%
# your code here

# %% [markdown]
# ### Get absolute path to directory d.

# %%
# your code here

# %% [markdown]
# ### Check if file f exists.

# %%
# your code here

# %% [markdown]
# ### Check if item f is a file.

# %%
# your code here

# %% [markdown]
# ### Formatted string with original/sale price and percent discount.

# %%
# your code here

# %% [markdown]
# ### Create empty set.

# %%
# your code here

# %% [markdown]
# ### Get size of set.

# %%
# your code here

# %% [markdown]
# ### Check if a in set s.

# %%
# your code here

# %% [markdown]
# ### Add a to set s.

# %%
# your code here

# %% [markdown]
# ### Print elements of s.

# %%
# your code here

# %% [markdown]
# ### Use list to check for duplicates in lst.

# %%
# your code here

# %% [markdown]
# ### Union of s1 and s2.

# %%
# your code here

# %% [markdown]
# ### Difference of s1 and s2.

# %%
# your code here

# %% [markdown]
# ### Intersection of s1 and s2.

# %%
# your code here

# %% [markdown]
# ### Check if s1 subset of s2.

# %%
# your code here

# %% [markdown]
# ### Use Counter to count items in lst.

# %%
# your code here

# %% [markdown]
# ### Combine counters c1 and c2.

# %%
# your code here

# %% [markdown]
# ### Create defaultdict mapping str→list.

# %%
# your code here

# %% [markdown]
# ### One‑line Celsius/Fahrenheit converter.

# %%
# your code here

# %% [markdown]
# ### One‑line rounding rule for float f.

# %%
# your code here

# %% [markdown]
# ### Declare class Box … and pickle.

# %%
# your code here

# %% [markdown]
# ### Graph + GraphNode + print_graph.

# %%
# your code here

# %% [markdown]
# ### ways(n) recursive with memo.

# %%
# your code here

# %% [markdown]
# ### Longest substring without repeats.

# %%
# your code here

# %% [markdown]
# ### Most frequent bigram.

# %%
# your code here

# %% [markdown]
# ### Min & max in one pass.

# %%
# your code here

# %% [markdown]
# ### Running statistics update.

# %%
# your code here

# %% [markdown]
# ### Find first duplicate.

# %%
# your code here

# %% [markdown]
# ### Open file safely with error.

# %%
# your code here

# %% [markdown]
# ### Divide two console numbers safely.

# %%
# your code here

# %% [markdown]
# ### Declare a class Box with __init__, __str__, getVolume; subclass Cube; pickle instance.

# %%
# your code here

# %% [markdown]
# ### Graph + GraphNode classes; print_graph traversal.

# %%
# your code here

# %% [markdown]
# ### Recursive ways(n) with memo for steps 1,3,5.

# %%
# your code here

# %% [markdown]
# ### Longest substring without repeated chars.

# %%
# your code here

# %% [markdown]
# ### Most frequent 2‑character substring (bigram).

# %%
# your code here

# %% [markdown]
# ### Function returning min and max in one pass.

# %%
# your code here

# %% [markdown]
# ### Update running statistics (count,total,mean).

# %%
# your code here

# %% [markdown]
# ### Find first duplicate in list.

# %%
# your code here

# %% [markdown]
# ### Open file safely with FileNotFoundError.

# %%
# your code here

# %% [markdown]
# ### Divide two console inputs with error handling.

# %%
# your code here
